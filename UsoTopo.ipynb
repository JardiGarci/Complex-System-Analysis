# %%
import numpy as np
import matplotlib.pyplot as plt
from Topology import Topology

# %%
img = np.array([[5,5,5,5,0,5,5,5],
                [5,1,5,5,1,0,5,5],
                [5,5,5,0,7,5,4,5],
                [5,5,2,6,2,2,5,5],
                [5,5,4,3,6,7,5,5],
                [5,1,5,5,7,2,5,5],
                [5,5,5,5,5,5,5,0]])
plt.imshow(img, cmap='gray')
plt.show()

topology = Topology(img)

print("Homology 0 lifetimes:", topology.lifetime_0)
print("Homology 1 lifetimes:", topology.lifetime_1)
# Out:
# Running...
# Homology 0 lifetimes: [[0, 8], [0, 1], [0, 5], [1, 5], [1, 4], [2, 5]]
# Homology 1 lifetimes: [[4, 7], [5, 7], [6, 7], [3, 6]]
